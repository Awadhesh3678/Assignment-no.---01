# %% [markdown]
# Question 1. What is the difference between a function and a method in Python?
#
# Answer-->  Function is nothing a block of code  that is defined using "def" keyword and these are defined out of the class, by simply
# * we can call the function where ever required directly.
# * def funtion_name()
#
#
# Method--> method are nothing other than function but  they are defined inside the class,  these can't be defined out of the class
#
# * And to call  method we need to first make the object of the class and then with the help of that object we call the method.

# %%
# Function
def greeting():
    print("Hello! How are u")

greeting()
# Out:
# Hello! How are u

# %%
# Method
class Class1:
    def greting(self):
        print("Hello from method!")

g = Class1()
g.greting()
# Out:
# Hello from method!

# %% [markdown]
# Question-2. Explain the concept of function arguments and parameters in Python ?
#
# Answer-->
#
# **Parameters**
# * Paramenters are nothing but the variable that we use while defining the funtion that declares or tells which type of input will the function take in it.
# * def square(x): --> x is a parameter here.
#
#
# **Arguments**
# * Arguments are the value that we pass in the function when we define it.
# * These are the one whose value are assigned to parameters and operated in function
# * square(10)  ---> 10 here is an argument.

# %%
def add(a, b):   # a,b are the parameters defined while defining the function
    return a + b

add(3, 5)  # 3,5 are the argumnets passed for the function
# Out:
# 8

# %% [markdown]
# Question-3.  What are the different ways to define and call a function in Python?
#
# Answer--> In Python,we can define and call functions in several ways depending on what we want the function to do. Here are the main types:
#
# * function no parameter --->def add()
# * function with parameter --->def add(a,b)
# * function with no return statement def add(a,b):  print(a+b)
#
# * function with return statement  ---> def add(a,b):   return a+b
# * Lambda function----> lambda a,b:a+b

# %%
# no parameter
def greeting():
    print("Hello!")

greeting()  # Function call
# Out:
# Hello!

# %%
# function with paramter
def add(a,b):
    print(a+b)

add(4,4)
# Out:
# 8

# %%
add = lambda a, b: a + b
print(add(4, 6))
# Out:
# 10

# %% [markdown]
# Question 4. What is the purpose of the `return` statement in a Python function?
#
# Answer--> `return` statement in python is simply used to return the value of operation performed in the function to place where it is called.
# * IT is a build in statement used to return hole statement at once.

# %%
# Example

def add(a,b):
  return (a+b)

result=add(45,45)
print(result)
# Out:
# 90

# %% [markdown]
# Question 5. What are iterators in Python and how do they differ from iterables?
#
#
# Answer--> **Iterators**
#
# Iterator are the objects that return/or give the values one by one at a time
# * we use _next(variable)--> use get value.
# * it first declare the variable as iterable  by `iter()` function. then with `next()` we get value
#
#
# `How they are duffernt`
# * iterators return value one by one
# * iterator uses two built in function iter() and next()
# * these are used whrn we want iterate over any data mannualy.

# %%
# Iterable
numbers = [10, 20, 30]   # This is iterable

# Iterator
iter = iter(numbers)       # This is now an iterator

print(next(iter))          # 10
print(next(iter))          # 20
# Out:
# 10
# 20

# %% [markdown]
# Question 6. Explain the concept of generators in Python and how they are defined ?
#
# Answer-->
# * A generator in Python is a special type of function that returns values one by one using the `yield` keyword instead of return.
# * Generator functions in Python are a way to create iterators in a more concise and memory-efficient mannerf
#
# * It is used when we want to generate a large sequence of values without storing them all in memory.
#
# `How they are defined`

# %%
def count_upto_5():
    for i in range(1, 6):
        yield i

gen = count_upto_5()

for num in gen:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Question 7. What are the advantages of using generators over regular functions?
#
# Answer-->
# Generators have many advantages over regular function as -----
# * Memory Efficient
# * Faster in Execution
# * Lazy Evaluatoin ::Generators produce one item at a time, only when requested (using next()).

# %% [markdown]
# Question-08. What is a lambda function in Python and when is it typically used?
#
# Answer--> Lambda function are the concise way to write anonymous funtion
# * these are aslo known as lambda expression as multi line can be replaced by simple one line
#
# * syntax--lambda arguments: expression
#
# `add = lambda a,b: a+b`
# * These are used when we
# * we want to shorten the c0de
# *  Define temporary funtion
# * we use lambda expression for small and concose code

# %%
# Using lambda to add two numbers
add = lambda x, y: x + y
print(add(3, 5))
# Out:
# 8

# %% [markdown]
# Question--09    Explain the purpose and usage of the `map()` function in Python.
#
#
# Answer-->  `map()` function in python  is used to compute the iterable with some specific  argument or function
# * It is used to map an objects of iterables
# * Syntax--> map(function, iterable)

# %%
# Example
l = ["1", "2", "3"]
list(map(lambda x: int(x), l))
# Out:
# [1, 2, 3]

# %% [markdown]
# Question--10  What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# Answer-->
# **map()**
# * map() function is used to map each item present i n iterable with some specific funtion .
# *  syntax-->  map(funtion, oiterable)
#
# **reduce()**
# * reduce funtion is used to supress the iterable by summing, multiplying,etc with its item  provideing the cummulative result.
# * it always work with 2 operand
# * syntax--> reduce(function,iterable)
#
# **filter()**
# * it is used to filter elements from an iterable based on some condition
# * syntax-->> filter(function, iterable)

# %% [markdown]
# Quesetion-->11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
#
# Answwer![pwQuestion-11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Practical Questions

# %%
# Q-01.  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in  the list.

def sum_of_even(list):
  sum=0
  for i in list:
     if(i%2==0):
        sum += i

  return sum


list=[1,2,3,4,4,5,6,7,8]
sum_of_even(list)
# Out:
# 24

# %%
# Q-02.   Create a Python function that accepts a string and returns the reverse of that string.

def reverse_string(string):
  return string[::-1]

string="abcdefghijk"
reverse_string(string)
# Out:
# 'kjihgfedcba'

# %%
# Q-03.  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def square_of_no(list):
  new_list=[]
  for i in list:
    new_list.append(i**2)

  return new_list

list=[1,2,5,7,9,5,4]
square_of_no(list)
# Out:
# [1, 4, 25, 49, 81, 25, 16]

# %%
# Q-04.  Write a Python function that checks if a given number is prime or not from 1 to 200.


def isprime(n):
  if n<2:
    return False
  for i in range(2,n):
    if n%i==0:
      return False
  return True
def check_prime():
  count=0
  for i in range(1,201):
    n=isprime(i)
    if n==True:
      count +=1     #counting prime
      print(f"{i} is prime")
    else:
        print(f"{i} is not prime")
  print()
  print(f"Total prime numbers are {count}")
check_prime()
# Out:
# 1 is not prime
# 2 is prime
# 3 is prime
# 4 is not prime
# 5 is prime
# 6 is not prime
# 7 is prime
# 8 is not prime
# 9 is not prime
# 10 is not prime
# 11 is prime
# 12 is not prime
# 13 is prime
# 14 is not prime
# 15 is not prime
# 16 is not prime
# 17 is prime
# 18 is not prime
# 19 is prime
# 20 is not prime
# 21 is not prime
# 22 is not prime
# 23 is prime
# 24 is not prime
# 25 is not prime
# 26 is not prime
# 27 is not prime
# 28 is not prime
# 29 is prime
# 30 is not prime
# 31 is prime
# 32 is not prime
# 33 is not prime
# 34 is not prime
# 35 is not prime
# 36 is not prime
# 37 is prime
# 38 is not prime
# 39 is not prime
# 40 is not prime
# 41 is prime
# 42 is not prime
# 43 is prime
# 44 is not prime
# 45 is not prime
# 46 is not prime
# 47 is prime
# 48 is not prime
# 49 is not prime
# 50 is not prime
# 51 is not prime
# 52 is not prime
# 53 is prime
# 54 is not prime
# 55 is not prime
# 56 is not prime
# 57 is not prime
# 58 is not prime
# 59 is prime
# ...

# %%
# Q-05. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
# Q-06. . Write a generator function in Python that yields the powers of 2 up to a given exponent

def power_of_2(n):
  for i in range(n + 1):
        yield 2 ** i


power_of_2(3)
# Out:
# <generator object power_of_2 at 0x7db1423d49e0>

# %%
n=power_of_2(3)

# %%
next(n)
# Out:
# 1

# %%
next(n)
# Out:
# 2

# %%
next(n)
# Out:
# 4

# %%
next(n)
# Out:
# 8

# %%
next(n)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-44-0fa053c92e6d> in <cell line: 0>()
# ----> 1 next(n)
#
# StopIteration:

# %%
# Q-07.  Implement a generator function that reads a file line by line and yields each line as a string

def read_file(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

for line in read_file('rudra.txt'):
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a0fa7f6b271e> in <cell line: 0>()
#       6             yield line.strip()
#       7
# ----> 8 for line in read_file('rudra.txt'):
#       9     print(line)
#      10
#
# <ipython-input-1-a0fa7f6b271e> in read_file(filename)
#       2
#       3 def read_file(filename):
# ----> 4     with open(filename, 'r') as file:
#       5         for line in file:
#       6             yield line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rudra.txt'

# %%
# Q-08.   Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
data = [(1, 1,4), (3, 1,7,8), (5,8, 2), (2, 3)]
sorted_data = sorted(data,key=lambda x: x[1])
print(sorted_data)
# Out:
# [(1, 1, 4), (3, 1, 7, 8), (2, 3), (5, 8, 2)]

# %%
# Q-09.  Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit

celsius=[0,10,52,45,20]
fehrenheit= list(map(lambda x: (x*9/5)+32,celsius))
fehrenheit
# Out:
# [32.0, 50.0, 125.6, 113.0, 68.0]

# %%
# Q-10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

def is_not_vowel(char):
    vowels = 'aeiouAEIOU'
    return char not in vowels

def remove_vowels(string):
    filtered_chars = filter(is_not_vowel, string)
    for char in filtered_chars:
        print(char, end='')


text = input("Enter a string: ")
remove_vowels(text)
# Out:
# Enter a string: adsajhaw]
# dsjhw]

# %%
#Q-11. Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.


orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

final_list = list(map(
    lambda order: (
        order[0],
        order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)
    ),orders))

print(final_list)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
